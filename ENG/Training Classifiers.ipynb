# %% [markdown]
# # Upload Data

# %% [markdown]
# **This section cannot be used yet, as the issue of copyright for some data sets is being resolved.**

# %% [markdown]
# dataset - Dataset Part 1
#
# dataset1 - Dataset Part 2

# %%
# !mkdir dataset
# !mkdir dataset1

# %%
# !unzip dataset/ACDC_Test_Drops.zip -d /content/dataset/
# !rm dataset/ACDC_Test_Drops.zip
# !unzip dataset/ACDC_Train_Drops.zip -d /content/dataset/
# !rm dataset/ACDC_Train_Drops.zip
# !unzip dataset/ACDC_Val_Drops.zip -d /content/dataset/
# !rm dataset/ACDC_Val_Drops.zip
# !unzip dataset/clean_acdc.zip -d /content/dataset/clean_acdc
# !rm dataset/clean_acdc.zip
# !unzip dataset/clean_test_acdc.zip -d /content/dataset/clean_test_acdc
# !rm dataset/clean_test_acdc.zip
# !unzip dataset/clean_test_woodscape.zip -d /content/dataset/clean_test_woodscape
# !rm dataset/clean_test_woodscape.zip
# !unzip dataset/defocus_test_woodscape.zip -d /content/dataset/defocus_test_woodscape
# !rm dataset/defocus_test_woodscape.zip
# !unzip dataset/drops_test_woodscape.zip -d /content/dataset/drops_test_woodscape
# !rm dataset/drops_test_woodscape.zip
# !unzip dataset/full_loss_test_woodscape.zip -d /content/dataset/full_loss_test_woodscape
# !rm dataset/full_loss_test_woodscape.zip
# !unzip dataset/motion_test_acdc.zip -d /content/dataset/motion_test_acdc
# !rm dataset/motion_test_acdc.zip
# !unzip dataset/motion_test_woodscape.zip -d /content/dataset/motion_test_woodscape
# !rm dataset/motion_test_woodscape.zip
# !unzip dataset/partial_test_woodscape.zip -d /content/dataset/partial_test_woodscape
# !rm dataset/partial_test_woodscape.zip
# !unzip dataset/SoilingDatasetNotFishEye_Test.zip -d /content/dataset/
# !rm dataset/SoilingDatasetNotFishEye_Test.zip
# !unzip dataset/SoilingDatasetNotFishEye_Train.zip -d /content/dataset/
# !rm dataset/SoilingDatasetNotFishEye_Train.zip
# !unzip dataset/spatter_acdc.zip -d /content/dataset/spatter_acdc
# !rm dataset/spatter_acdc.zip
# !unzip dataset/spatter_test_acdc.zip -d /content/dataset/spatter_test_acdc
# !rm dataset/spatter_test_acdc.zip
# !unzip dataset/Tapmer_Test_FullLoss.zip -d /content/dataset/
# !rm dataset/Tapmer_Test_FullLoss.zip
# !unzip dataset/Tapmer_Train_FullLoss.zip -d /content/dataset/
# !rm dataset/Tapmer_Train_FullLoss.zip

# %%
# !unzip dataset1/clean_driving.zip -d /content/dataset1/clean_driving
# !rm dataset1/clean_driving.zip
# !unzip dataset1/clean_woodscape.zip -d /content/dataset1/clean_woodscape
# !rm dataset1/clean_woodscape.zip
# !unzip dataset1/defocus_acdc.zip -d /content/dataset1/defocus_acdc
# !rm dataset1/defocus_acdc.zip
# !unzip dataset1/defocus_driving.zip -d /content/dataset1/defocus_driving
# !rm dataset1/defocus_driving.zip
# !unzip dataset1/defocus_woodscape.zip -d /content/dataset1/defocus_woodscape
# !rm dataset1/defocus_woodscape.zip
# !unzip dataset1/defocus_test_acdc.zip -d /content/dataset1/defocus_test_acdc
# !rm dataset1/defocus_test_acdc.zip
# !unzip dataset1/drops_woodscape.zip -d /content/dataset1/drops_woodscape
# !rm dataset1/drops_woodscape.zip
# !unzip dataset1/full_loss_acdc_1000.zip -d /content/dataset1/full_loss_acdc_1000
# !rm dataset1/full_loss_acdc_1000.zip
# !unzip dataset1/full_loss_woodscape.zip -d /content/dataset1/full_loss_woodscape
# !rm dataset1/full_loss_woodscape.zip
# !unzip dataset1/motion_acdc.zip -d /content/dataset1/motion_acdc
# !rm dataset1/motion_acdc.zip
# !unzip dataset1/motion_driving.zip -d /content/dataset1/motion_driving
# !rm dataset1/motion_driving.zip
# !unzip dataset1/motion_woodscape.zip -d /content/dataset1/motion_woodscape
# !rm dataset1/motion_woodscape.zip
# !unzip dataset1/partial_woodscape.zip -d /content/dataset1/partial_woodscape
# !rm dataset1/partial_woodscape.zip

# %%
# !mv dataset/SoilingDatasetNotFishEye_Test /content/
# !mv dataset/SoilingDatasetNotFishEye_Train /content/

# !mv SoilingDatasetNotFishEye_Test test
# !mv SoilingDatasetNotFishEye_Train train

# %% [markdown]
# Question: Why we use dirs.sort()?
#
# Answer: https://stackoverflow.com/questions/54773598/os-walk-different-folder-ordering-on-mac-and-linux

# %%
# Tamper
# !bash -c 'mv dataset/Tapmer_Train_FullLoss/*.* /content/train/full'
# !bash -c 'mv dataset/Tapmer_Test_FullLoss/*.* /content/test/full'

# %%
import os

root = ""
dir_name = "dataset1/full_loss_acdc_1000/full_loss"
for root, dirs, files in os.walk(os.path.join(root, dir_name)):
  dirs.sort()
  i = 0
  j = 0
  for file in files:
    image_name = os.path.join(root, file)
    #print(image_name.split('/')[3])
    os.replace(image_name, "test/full/" + image_name.split('/')[3])
    i = i + 1
    if i == 93: break
  print(i)
  #with open('driving-stereo-1000k', 'wb') as fp:
  #  pickle.dump(info, fp)  
  break

root = ""
dir_name = "dataset1/full_loss_woodscape/full_loss"
for root, dirs, files in os.walk(os.path.join(root, dir_name)):
  dirs.sort()
  i = 0
  j = 0
  for file in files:
    image_name = os.path.join(root, file)
    #print(image_name.split('/')[3])
    os.replace(image_name, "test/full/" + image_name.split('/')[3])
    i = i + 1
    if i == 92: break
  print(i)
  #with open('driving-stereo-1000k', 'wb') as fp:
  #  pickle.dump(info, fp)  
  break

root = ""
dir_name = "dataset/full_loss_test_woodscape/full_loss_test"
for root, dirs, files in os.walk(os.path.join(root, dir_name)):
  dirs.sort()
  i = 0
  j = 0
  for file in files:
    image_name = os.path.join(root, file)
    #print(image_name.split('/')[3])
    os.replace(image_name, "test/full/" + image_name.split('/')[3])
    i = i + 1
    if i == 92: break
  print(i)
  #with open('driving-stereo-1000k', 'wb') as fp:
  #  pickle.dump(info, fp)  
  break
# Out:
# 93
# 92
# 92

# %%
# %cd test/full/
# !ls -l | wc
# %cd /content/
# Out:
# /content/test/full
#     614    5807   38901
# /content

# %%
root = ""
dir_name = "dataset1/full_loss_acdc_1000/full_loss"
for root, dirs, files in os.walk(os.path.join(root, dir_name)):
  dirs.sort()
  i = 0
  j = 0
  for file in files:
    image_name = os.path.join(root, file)
    #print(image_name.split('/')[3])
    os.replace(image_name, "train/full/" + image_name.split('/')[3])
    i = i + 1
    #if i == 93: break
  print(i)
  #with open('driving-stereo-1000k', 'wb') as fp:
  #  pickle.dump(info, fp)  
  break
# Out:
# 0

# %%
root = ""
dir_name = "dataset1/full_loss_woodscape/full_loss"
for root, dirs, files in os.walk(os.path.join(root, dir_name)):
  dirs.sort()
  i = 0
  j = 0
  for file in files:
    image_name = os.path.join(root, file)
    #print(image_name.split('/')[3])
    os.replace(image_name, "train/full/" + image_name.split('/')[3])
    i = i + 1
    #if i == 92: break
  print(i)
  #with open('driving-stereo-1000k', 'wb') as fp:
  #  pickle.dump(info, fp)  
  break
# Out:
# 0

# %%
root = ""
dir_name = "dataset/full_loss_test_woodscape/full_loss_test"
for root, dirs, files in os.walk(os.path.join(root, dir_name)):
  dirs.sort()
  i = 0
  j = 0
  for file in files:
    image_name = os.path.join(root, file)
    #print(image_name.split('/')[3])
    os.replace(image_name, "train/full/" + image_name.split('/')[3])
    i = i + 1
    #if i == 110: break
  print(i)
  #with open('driving-stereo-1000k', 'wb') as fp:
  #  pickle.dump(info, fp)  
  break
# Out:
# 0

# %% [markdown]
# Defocus

# %%
# !mkdir train/defocus
# !mkdir test/defocus

root = ""
dir_name = "dataset1/defocus_acdc/defocus"
for root, dirs, files in os.walk(os.path.join(root, dir_name)):
  dirs.sort()
  i = 0
  j = 0
  for file in files:
    image_name = os.path.join(root, file)
    #print(image_name.split('/')[3])
    os.replace(image_name, "test/defocus/" + image_name.split('/')[3])
    i = i + 1
    if i == 205: break
  print(i)
  #with open('driving-stereo-1000k', 'wb') as fp:
  #  pickle.dump(info, fp)  
  break

root = ""
dir_name = "dataset/defocus_test_woodscape/defocus_test"
for root, dirs, files in os.walk(os.path.join(root, dir_name)):
  dirs.sort()
  i = 0
  j = 0
  for file in files:
    image_name = os.path.join(root, file)
    #print(image_name.split('/')[3])
    os.replace(image_name, "test/defocus/" + image_name.split('/')[3])
    i = i + 1
    if i == 205: break
  print(i)
  #with open('driving-stereo-1000k', 'wb') as fp:
  #  pickle.dump(info, fp)  
  break

root = ""
dir_name = "dataset1/defocus_driving/defocus_driving"
for root, dirs, files in os.walk(os.path.join(root, dir_name)):
  dirs.sort()
  i = 0
  j = 0
  for file in files:
    image_name = os.path.join(root, file)
    #print(image_name.split('/')[3])
    os.replace(image_name, "test/defocus/" + image_name.split('/')[3])
    i = i + 1
    if i == 87: break
  print(i)
  #with open('driving-stereo-1000k', 'wb') as fp:
  #  pickle.dump(info, fp)  
  break

root = ""
dir_name = "dataset1/defocus_test_acdc/defocus"
for root, dirs, files in os.walk(os.path.join(root, dir_name)):
  dirs.sort()
  i = 0
  j = 0
  for file in files:
    image_name = os.path.join(root, file)
    #print(image_name.split('/')[3])
    os.replace(image_name, "test/defocus/" + image_name.split('/')[3])
    i = i + 1
    if i == 102: break
  print(i)
  #with open('driving-stereo-1000k', 'wb') as fp:
  #  pickle.dump(info, fp)  
  break
# Out:
# 205
# 205
# 87
# 102

# %%
# %cd test/defocus/
# !ls -l | wc
# %cd /content/
# Out:
# /content/test/defocus
#     600    5393   45025
# /content

# %%
root = ""
dir_name = "dataset1/defocus_acdc/defocus"
for root, dirs, files in os.walk(os.path.join(root, dir_name)):
  dirs.sort()
  i = 0
  j = 0
  for file in files:
    image_name = os.path.join(root, file)
    #print(image_name.split('/')[3])
    os.replace(image_name, "train/defocus/" + image_name.split('/')[3])
    i = i + 1
    #if i == 205: break
  print(i)
  #with open('driving-stereo-1000k', 'wb') as fp:
  #  pickle.dump(info, fp)  
  break

root = ""
dir_name = "dataset/defocus_test_woodscape/defocus_test"
for root, dirs, files in os.walk(os.path.join(root, dir_name)):
  dirs.sort()
  i = 0
  j = 0
  for file in files:
    image_name = os.path.join(root, file)
    #print(image_name.split('/')[3])
    os.replace(image_name, "train/defocus/" + image_name.split('/')[3])
    i = i + 1
    #if i == 205: break
  print(i)
  #with open('driving-stereo-1000k', 'wb') as fp:
  #  pickle.dump(info, fp)  
  break

root = ""
dir_name = "dataset1/defocus_driving/defocus_driving"
for root, dirs, files in os.walk(os.path.join(root, dir_name)):
  dirs.sort()
  i = 0
  j = 0
  for file in files:
    image_name = os.path.join(root, file)
    #print(image_name.split('/')[3])
    os.replace(image_name, "train/defocus/" + image_name.split('/')[3])
    i = i + 1
    #if i == 102: break
  print(i)
  #with open('driving-stereo-1000k', 'wb') as fp:
  #  pickle.dump(info, fp)  
  break

root = ""
dir_name = "dataset1/defocus_test_acdc/defocus"
for root, dirs, files in os.walk(os.path.join(root, dir_name)):
  dirs.sort()
  i = 0
  j = 0
  for file in files:
    image_name = os.path.join(root, file)
    #print(image_name.split('/')[3])
    os.replace(image_name, "train/defocus/" + image_name.split('/')[3])
    i = i + 1
    #if i == 102: break
  print(i)
  #with open('driving-stereo-1000k', 'wb') as fp:
  #  pickle.dump(info, fp)  
  break

root = ""
dir_name = "dataset1/defocus_woodscape/defocus"
for root, dirs, files in os.walk(os.path.join(root, dir_name)):
  dirs.sort()
  i = 0
  j = 0
  for file in files:
    image_name = os.path.join(root, file)
    #print(image_name.split('/')[3])
    os.replace(image_name, "train/defocus/" + image_name.split('/')[3])
    i = i + 1
    #if i == 102: break
  print(i)
  #with open('driving-stereo-1000k', 'wb') as fp:
  #  pickle.dump(info, fp)  
  break
# Out:
# 0
# 0
# 0
# 0
# 0

# %% [markdown]
# Motion

# %%
# !mkdir train/motion
# !mkdir test/motion

root = ""
dir_name = "dataset1/motion_acdc/motion"
for root, dirs, files in os.walk(os.path.join(root, dir_name)):
  dirs.sort()
  i = 0
  j = 0
  for file in files:
    image_name = os.path.join(root, file)
    #print(image_name.split('/')[3])
    os.replace(image_name, "test/motion/" + image_name.split('/')[3])
    i = i + 1
    if i == 205: break
  print(i)
  #with open('driving-stereo-1000k', 'wb') as fp:
  #  pickle.dump(info, fp)  
  break

root = ""
dir_name = "dataset/motion_test_woodscape/motion_test"
for root, dirs, files in os.walk(os.path.join(root, dir_name)):
  dirs.sort()
  i = 0
  j = 0
  for file in files:
    image_name = os.path.join(root, file)
    #print(image_name.split('/')[3])
    os.replace(image_name, "test/motion/" + image_name.split('/')[3])
    i = i + 1
    if i == 205: break
  print(i)
  #with open('driving-stereo-1000k', 'wb') as fp:
  #  pickle.dump(info, fp)  
  break

root = ""
dir_name = "dataset1/motion_driving/motion_driving"
for root, dirs, files in os.walk(os.path.join(root, dir_name)):
  dirs.sort()
  i = 0
  j = 0
  for file in files:
    image_name = os.path.join(root, file)
    #print(image_name.split('/')[3])
    os.replace(image_name, "test/motion/" + image_name.split('/')[3])
    i = i + 1
    if i == 87: break
  print(i)
  #with open('driving-stereo-1000k', 'wb') as fp:
  #  pickle.dump(info, fp)  
  break

root = ""
dir_name = "dataset/motion_test_acdc/motion"
for root, dirs, files in os.walk(os.path.join(root, dir_name)):
  dirs.sort()
  i = 0
  j = 0
  for file in files:
    image_name = os.path.join(root, file)
    #print(image_name.split('/')[3])
    os.replace(image_name, "test/motion/" + image_name.split('/')[3])
    i = i + 1
    if i == 102: break
  print(i)
  #with open('driving-stereo-1000k', 'wb') as fp:
  #  pickle.dump(info, fp)  
  break
# Out:
# 205
# 205
# 87
# 102

# %%
root = ""
dir_name = "dataset1/motion_acdc/motion"
for root, dirs, files in os.walk(os.path.join(root, dir_name)):
  dirs.sort()
  i = 0
  j = 0
  for file in files:
    image_name = os.path.join(root, file)
    #print(image_name.split('/')[3])
    os.replace(image_name, "train/motion/" + image_name.split('/')[3])
    i = i + 1
    #if i == 205: break
  print(i)
  #with open('driving-stereo-1000k', 'wb') as fp:
  #  pickle.dump(info, fp)  
  break

root = ""
dir_name = "dataset/motion_test_woodscape/motion_test"
for root, dirs, files in os.walk(os.path.join(root, dir_name)):
  dirs.sort()
  i = 0
  j = 0
  for file in files:
    image_name = os.path.join(root, file)
    #print(image_name.split('/')[3])
    os.replace(image_name, "train/motion/" + image_name.split('/')[3])
    i = i + 1
    #if i == 205: break
  print(i)
  #with open('driving-stereo-1000k', 'wb') as fp:
  #  pickle.dump(info, fp)  
  break

root = ""
dir_name = "dataset1/motion_driving/motion_driving"
for root, dirs, files in os.walk(os.path.join(root, dir_name)):
  dirs.sort()
  i = 0
  j = 0
  for file in files:
    image_name = os.path.join(root, file)
    #print(image_name.split('/')[3])
    os.replace(image_name, "train/motion/" + image_name.split('/')[3])
    i = i + 1
    #if i == 102: break
  print(i)
  #with open('driving-stereo-1000k', 'wb') as fp:
  #  pickle.dump(info, fp)  
  break

root = ""
dir_name = "dataset/motion_test_acdc/motion"
for root, dirs, files in os.walk(os.path.join(root, dir_name)):
  dirs.sort()
  i = 0
  j = 0
  for file in files:
    image_name = os.path.join(root, file)
    #print(image_name.split('/')[3])
    os.replace(image_name, "train/motion/" + image_name.split('/')[3])
    i = i + 1
    #if i == 102: break
  print(i)
  #with open('driving-stereo-1000k', 'wb') as fp:
  #  pickle.dump(info, fp)  
  break
# Out:
# 0
# 0
# 0
# 0

# %%
root = ""
dir_name = "dataset1/motion_woodscape/motion"
for root, dirs, files in os.walk(os.path.join(root, dir_name)):
  dirs.sort()
  i = 0
  j = 0
  for file in files:
    image_name = os.path.join(root, file)
    #print(image_name.split('/')[3])
    os.replace(image_name, "train/motion/" + image_name.split('/')[3])
    i = i + 1
    #if i == 102: break
  print(i)
  #with open('driving-stereo-1000k', 'wb') as fp:
  #  pickle.dump(info, fp)  
  break
# Out:
# 0

# %% [markdown]
# Partial

# %%
root = ""
dir_name = "dataset/spatter_test_acdc/spatter"
for root, dirs, files in os.walk(os.path.join(root, dir_name)):
  dirs.sort()
  i = 0
  j = 0
  for file in files:
    image_name = os.path.join(root, file)
    #print(image_name.split('/')[3])
    os.replace(image_name, "test/partial/" + image_name.split('/')[3])
    i = i + 1
    if i == 225: break
  print(i)
  #with open('driving-stereo-1000k', 'wb') as fp:
  #  pickle.dump(info, fp)  
  break

root = ""
dir_name = "dataset/partial_test_woodscape/partial_test"
for root, dirs, files in os.walk(os.path.join(root, dir_name)):
  dirs.sort()
  i = 0
  j = 0
  for file in files:
    image_name = os.path.join(root, file)
    #print(image_name.split('/')[3])
    os.replace(image_name, "test/partial/" + image_name.split('/')[3])
    i = i + 1
    if i == 210: break
  print(i)
  #with open('driving-stereo-1000k', 'wb') as fp:
  #  pickle.dump(info, fp)  
  break
# Out:
# 225
# 210

# %%
root = ""
dir_name = "dataset/spatter_acdc/spatter"
for root, dirs, files in os.walk(os.path.join(root, dir_name)):
  dirs.sort()
  i = 0
  j = 0
  for file in files:
    image_name = os.path.join(root, file)
    #print(image_name.split('/')[3])
    os.replace(image_name, "train/partial/" + image_name.split('/')[3])
    i = i + 1
    #if i == 205: break
  print(i)
  #with open('driving-stereo-1000k', 'wb') as fp:
  #  pickle.dump(info, fp)  
  break

root = ""
dir_name = "dataset/spatter_test_acdc/spatter"
for root, dirs, files in os.walk(os.path.join(root, dir_name)):
  dirs.sort()
  i = 0
  j = 0
  for file in files:
    image_name = os.path.join(root, file)
    #print(image_name.split('/')[3])
    os.replace(image_name, "train/partial/" + image_name.split('/')[3])
    i = i + 1
    #if i == 205: break
  print(i)
  #with open('driving-stereo-1000k', 'wb') as fp:
  #  pickle.dump(info, fp)  
  break

root = ""
dir_name = "dataset/partial_test_woodscape/partial_test"
for root, dirs, files in os.walk(os.path.join(root, dir_name)):
  dirs.sort()
  i = 0
  j = 0
  for file in files:
    image_name = os.path.join(root, file)
    #print(image_name.split('/')[3])
    os.replace(image_name, "train/partial/" + image_name.split('/')[3])
    i = i + 1
    #if i == 102: break
  print(i)
  #with open('driving-stereo-1000k', 'wb') as fp:
  #  pickle.dump(info, fp)  
  break

root = ""
dir_name = "dataset1/partial_woodscape/partial"
for root, dirs, files in os.walk(os.path.join(root, dir_name)):
  dirs.sort()
  i = 0
  j = 0
  for file in files:
    image_name = os.path.join(root, file)
    #print(image_name.split('/')[3])
    os.replace(image_name, "train/partial/" + image_name.split('/')[3])
    i = i + 1
    #if i == 102: break
  print(i)
  #with open('driving-stereo-1000k', 'wb') as fp:
  #  pickle.dump(info, fp)  
  break
# Out:
# 0
# 0
# 0
# 0

# %% [markdown]
# Drops

# %%
# !mv dataset/ACDC_Val_Drops/*.* test/drops

root = ""
dir_name = "dataset/ACDC_Train_Drops"
for root, dirs, files in os.walk(os.path.join(root, dir_name)):
  dirs.sort()
  i = 0
  j = 0
  for file in files:
    image_name = os.path.join(root, file)
    #print(image_name.split('/')[3])
    os.replace(image_name, "test/drops/" + image_name.split('/')[2])
    i = i + 1
    if i == 181: break
  print(i)
  #with open('driving-stereo-1000k', 'wb') as fp:
  #  pickle.dump(info, fp)  
  break

root = ""
dir_name = "dataset/drops_test_woodscape/drops_test"
for root, dirs, files in os.walk(os.path.join(root, dir_name)):
  dirs.sort()
  i = 0
  j = 0
  for file in files:
    image_name = os.path.join(root, file)
    #print(image_name.split('/')[3])
    os.replace(image_name, "test/drops/" + image_name.split('/')[3])
    i = i + 1
    if i == 181: break
  print(i)
  #with open('driving-stereo-1000k', 'wb') as fp:
  #  pickle.dump(info, fp)  
  break
# Out:
# 181
# 181

# %%
# !mv dataset/ACDC_Test_Drops/*.* train/drops

root = ""
dir_name = "dataset/ACDC_Train_Drops"
for root, dirs, files in os.walk(os.path.join(root, dir_name)):
  dirs.sort()
  i = 0
  j = 0
  for file in files:
    image_name = os.path.join(root, file)
    #print(image_name.split('/')[3])
    os.replace(image_name, "train/drops/" + image_name.split('/')[2])
    i = i + 1
    #if i == 362: break
  print(i)
  #with open('driving-stereo-1000k', 'wb') as fp:
  #  pickle.dump(info, fp)  
  break

root = ""
dir_name = "dataset/drops_test_woodscape/drops_test"
for root, dirs, files in os.walk(os.path.join(root, dir_name)):
  dirs.sort()
  i = 0
  j = 0
  for file in files:
    image_name = os.path.join(root, file)
    #print(image_name.split('/')[3])
    os.replace(image_name, "train/drops/" + image_name.split('/')[3])
    i = i + 1
    #if i == 181: break
  print(i)
  #with open('driving-stereo-1000k', 'wb') as fp:
  #  pickle.dump(info, fp)  
  break

root = ""
dir_name = "dataset1/drops_woodscape/drops"
for root, dirs, files in os.walk(os.path.join(root, dir_name)):
  dirs.sort()
  i = 0
  j = 0
  for file in files:
    image_name = os.path.join(root, file)
    #print(image_name.split('/')[3])
    os.replace(image_name, "train/drops/" + image_name.split('/')[3])
    i = i + 1
    #if i == 181: break
  print(i)
  #with open('driving-stereo-1000k', 'wb') as fp:
  #  pickle.dump(info, fp)  
  break
# Out:
# mv: cannot stat 'dataset/ACDC_Test_Drops/*.*': No such file or directory
# 0
# 0
# 0

# %% [markdown]
# Clean

# %%
root = ""
dir_name = "dataset/clean_test_acdc/clean"
for root, dirs, files in os.walk(os.path.join(root, dir_name)):
  dirs.sort()
  i = 0
  j = 0
  for file in files:
    image_name = os.path.join(root, file)
    #print(image_name.split('/')[3])
    os.replace(image_name, "test/clean/" + image_name.split('/')[3])
    i = i + 1
    if i == 202: break
  print(i)
  #with open('driving-stereo-1000k', 'wb') as fp:
  #  pickle.dump(info, fp)  
  break

root = ""
dir_name = "dataset/clean_test_woodscape/clean_test"
for root, dirs, files in os.walk(os.path.join(root, dir_name)):
  dirs.sort()
  i = 0
  j = 0
  for file in files:
    image_name = os.path.join(root, file)
    #print(image_name.split('/')[3])
    os.replace(image_name, "test/clean/" + image_name.split('/')[3])
    i = i + 1
    if i == 202: break
  print(i)
  #with open('driving-stereo-1000k', 'wb') as fp:
  #  pickle.dump(info, fp)  
  break

root = ""
dir_name = "dataset1/clean_driving/clean_driving"
for root, dirs, files in os.walk(os.path.join(root, dir_name)):
  dirs.sort()
  i = 0
  j = 0
  for file in files:
    image_name = os.path.join(root, file)
    #print(image_name.split('/')[3])
    os.replace(image_name, "test/clean/" + image_name.split('/')[3])
    i = i + 1
    if i == 202: break
  print(i)
  #with open('driving-stereo-1000k', 'wb') as fp:
  #  pickle.dump(info, fp)  
  break
# Out:
# 202
# 202
# 202

# %%
root = ""
dir_name = "dataset/clean_test_acdc/clean"
for root, dirs, files in os.walk(os.path.join(root, dir_name)):
  dirs.sort()
  i = 0
  j = 0
  for file in files:
    image_name = os.path.join(root, file)
    #print(image_name.split('/')[3])
    os.replace(image_name, "train/clean/" + image_name.split('/')[3])
    i = i + 1
    #if i == 202: break
  print(i)
  #with open('driving-stereo-1000k', 'wb') as fp:
  #  pickle.dump(info, fp)  
  break

root = ""
dir_name = "dataset/clean_acdc/clean"
for root, dirs, files in os.walk(os.path.join(root, dir_name)):
  dirs.sort()
  i = 0
  j = 0
  for file in files:
    image_name = os.path.join(root, file)
    #print(image_name.split('/')[3])
    os.replace(image_name, "train/clean/" + image_name.split('/')[3])
    i = i + 1
    #if i == 202: break
  print(i)
  #with open('driving-stereo-1000k', 'wb') as fp:
  #  pickle.dump(info, fp)  
  break

root = ""
dir_name = "dataset/clean_test_woodscape/clean_test"
for root, dirs, files in os.walk(os.path.join(root, dir_name)):
  dirs.sort()
  i = 0
  j = 0
  for file in files:
    image_name = os.path.join(root, file)
    #print(image_name.split('/')[3])
    os.replace(image_name, "train/clean/" + image_name.split('/')[3])
    i = i + 1
    #if i == 202: break
  print(i)
  #with open('driving-stereo-1000k', 'wb') as fp:
  #  pickle.dump(info, fp)  
  break

root = ""
dir_name = "dataset1/clean_driving/clean_driving"
for root, dirs, files in os.walk(os.path.join(root, dir_name)):
  dirs.sort()
  i = 0
  j = 0
  for file in files:
    image_name = os.path.join(root, file)
    #print(image_name.split('/')[3])
    os.replace(image_name, "train/clean/" + image_name.split('/')[3])
    i = i + 1
    #if i == 85: break
  print(i)
  #with open('driving-stereo-1000k', 'wb') as fp:
  #  pickle.dump(info, fp)  
  break

root = ""
dir_name = "dataset1/clean_woodscape/clean"
for root, dirs, files in os.walk(os.path.join(root, dir_name)):
  dirs.sort()
  i = 0
  j = 0
  for file in files:
    image_name = os.path.join(root, file)
    #print(image_name.split('/')[3])
    os.replace(image_name, "train/clean/" + image_name.split('/')[3])
    i = i + 1
    #if i == 202: break
  print(i)
  #with open('driving-stereo-1000k', 'wb') as fp:
  #  pickle.dump(info, fp)  
  break
# Out:
# 0
# 0
# 0
# 0
# 0

# %%
# !pip install ml-collections

# %%
import torch
import os
import cv2
import imgaug as ia
import numpy as np
import sys
import json

from imgaug import augmenters as iaa

from collections import defaultdict

from torch.utils.data import Dataset, DataLoader
from torch import nn
from torch.nn import functional as F

from torchvision.models import resnet18 as resnet18
from torchvision import transforms

import matplotlib.pyplot as plt

# %%
# !pip install imgaug wandb

# %% [markdown]
# # Logging the training process

# %%
# %pip install wandb -q
import wandb
wandb.login()

# %%
import wandb
wandb.init(project='', entity='')
None

# %%
import wandb

# %% [markdown]
# # Data preparation

# %%
# !mkdir train
# !mkdir test

# %%
# !mkdir train/{motion,clean,drops,full,partial,strong,defocus}
# !mkdir test/{motion,clean,drops,full,partial,strong,defocus}

# %%
TRAIN_DATA_PATH = 'train/'
TEST_DATA_PATH = 'test/'

# %% [markdown]
# Config

# %%
BATCH_SIZE = 64
TRAIN_LEN = 0
TEST_LEN = 0
IMAGE_WIDTH = 224
IMAGE_HEIGHT = 224
NUM_WORKERS = 4
EPOCHS = 5
DEVICE = 'cuda'
SEED = 2020
SPLIT_DATA = 0.2
LR = 0.0001
MODEL_DESC = ''

# %%
class VehiclesDatasetDisk(Dataset):

    def __init__(self, path, transform=None):
        super().__init__()

        self.path = path
        self.transform = transform

        self.data = []

        self.class_name_to_idx = {}
        self.idx_to_class_name = []

        for class_idx, class_name in enumerate(sorted(os.listdir(path))):
            self.class_name_to_idx[class_name] = class_idx
            self.idx_to_class_name.append(class_name)

            class_images_path = os.path.join(path, class_name)
            for image_name in os.listdir(class_images_path):
                image_path = os.path.join(class_images_path, image_name)
                
                # remember the path to the image, we will read it later
                self.data.append((image_path, class_name))

    def __getitem__(self, idx):
        image_path, class_name = self.data[idx]
        # disk reading and decoding jpeg
        image = cv2.imread(image_path, cv2.IMREAD_COLOR)
        if self.transform:
            image = self.transform(image)
        return image, self.class_name_to_idx[class_name]

    def __len__(self):
        return len(self.data)

# %%
train_transform = transforms.Compose([
    iaa.Sequential([
        #iaa.Fliplr(0.5),
        iaa.Resize({"height": IMAGE_HEIGHT, "width": IMAGE_WIDTH})
    ]).augment_image,
    transforms.ToTensor(),
    transforms.Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225))
])

test_transform = transforms.Compose([
    iaa.Sequential([
        iaa.Resize({"height": IMAGE_HEIGHT, "width": IMAGE_WIDTH})
    ]).augment_image,
    transforms.ToTensor(),
    transforms.Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225))
])

# %%
train_dataset = VehiclesDatasetDisk(TRAIN_DATA_PATH, train_transform)
test_dataset = VehiclesDatasetDisk(TEST_DATA_PATH, test_transform)

TRAIN_LEN = len(train_dataset)
TEST_LEN = len(test_dataset)

print('Train dataset size:', len(train_dataset))
print('Test dataset size:', len(test_dataset))
# Out:
# Train dataset size: 18584
# Test dataset size: 4397

# %%
image, class_idx = train_dataset[6]

print('Image shape:', image.shape)
print('Class idx:', class_idx)
print('Class name:', train_dataset.idx_to_class_name[class_idx])

plt.imshow(image[1], cmap='Greys_r')
# Out:
# Image shape: torch.Size([3, 224, 224])
# Class idx: 0
# Class name: clean

# %%
train_dataloader = DataLoader(
    train_dataset,
    batch_size=BATCH_SIZE,
    shuffle=True,
    num_workers=NUM_WORKERS,
    pin_memory=True,
    drop_last=True
)

test_dataloader = DataLoader(
    test_dataset,  
    batch_size=BATCH_SIZE, 
    shuffle=False,
    num_workers=NUM_WORKERS, 
    pin_memory=True, 
    drop_last=False
)

# %% [markdown]
# # Prepare a model ResNet-18

# %%
from torchvision.models import resnet34 as resnet34

model = resnet18(pretrained=True)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
#   0%|          | 0.00/44.7M [00:00<?, ?B/s]

# %%
num_ftrs = model.fc.in_features
model.fc = nn.Linear(num_ftrs, 7)
torch.nn.init.xavier_normal_(model.fc.weight)
model

# %%
# Freeze all the weights of the model
for param in model.parameters():
    param.requires_grad = False

# Unfreeze last linear layer
for param in model.fc.parameters():
    param.requires_grad = True

# %%
print('Total number of parameters:', sum(param.numel() for param in model.parameters()))
# Out:
# Total number of parameters: 11180103

# %%
print('Number of trainable parameters:', sum(param.numel() for param in model.parameters() if param.requires_grad))
# Out:
# Number of trainable parameters: 3591

# %%
if torch.cuda.is_available():
    model = model.cuda()

# %% [markdown]
# # Prepare a model ResNet-34

# %%
from torchvision.models import resnet34 as resnet34

model = resnet34(pretrained=True)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
#   0%|          | 0.00/44.7M [00:00<?, ?B/s]

# %%
num_ftrs = model.fc.in_features
model.fc = nn.Linear(num_ftrs, 7)
torch.nn.init.xavier_normal_(model.fc.weight)
model

# %%
# Freeze all the weights of the model
for param in model.parameters():
    param.requires_grad = False

# Unfreeze last linear layer
for param in model.fc.parameters():
    param.requires_grad = True

# %%
print('Total number of parameters:', sum(param.numel() for param in model.parameters()))

# %%
print('Number of trainable parameters:', sum(param.numel() for param in model.parameters() if param.requires_grad))

# %%
if torch.cuda.is_available():
    model = model.cuda()

# %% [markdown]
# # Prepare a model ResNeXt50

# %%
import torchvision

model = torchvision.models.resnext50_32x4d(pretrained=True)

# %%
num_ftrs = model.fc.in_features
model.fc = nn.Linear(num_ftrs, 7)
torch.nn.init.xavier_normal_(model.fc.weight)
model

# %%
# Freeze all the weights of the model
for param in model.parameters():
    param.requires_grad = False

# Unfreeze last linear layer
for param in model.fc.parameters():
    param.requires_grad = True

# %%
print('Total number of parameters:', sum(param.numel() for param in model.parameters()))

# %%
print('Number of trainable parameters:', sum(param.numel() for param in model.parameters() if param.requires_grad))

# %%
if torch.cuda.is_available():
    model = model.cuda()

# %% [markdown]
# # Prepare a model EfficientNet_B0

# %%
# !pip install timm

# %%
import timm

model = timm.create_model('efficientnet_b0', num_classes=7, pretrained=True)
# Out:
# Downloading: "https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-weights/efficientnet_b0_ra-3dd342df.pth" to /root/.cache/torch/hub/checkpoints/efficientnet_b0_ra-3dd342df.pth

# %%
# Freeze all the weights of the model
for param in model.parameters():
    param.requires_grad = False

# Unfreeze last linear layer
model.head = nn.Linear(1280,7)

# %%
print('Total number of parameters:', sum(param.numel() for param in model.parameters()))

# %%
print('Number of trainable parameters:', sum(param.numel() for param in model.parameters() if param.requires_grad))

# %%
if torch.cuda.is_available():
    model = model.cuda()

# %% [markdown]
# # Prepare a model ViT-Tiny

# %%
# !pip install timm

# %%
import timm

model = timm.create_model('vit_tiny_patch16_224', num_classes=7, pretrained=True)

# %%
# Freeze all the weights of the model
for param in model.parameters():
    param.requires_grad = False

# Unfreeze last linear layer
model.head = nn.Linear(192,7)

# %%
print('Total number of parameters:', sum(param.numel() for param in model.parameters()))

# %%
print('Number of trainable parameters:', sum(param.numel() for param in model.parameters() if param.requires_grad))

# %%
if torch.cuda.is_available():
    model = model.cuda()

# %% [markdown]
# # Prepare a model DeiT-Tiny

# %%
# !pip install timm

# %%
import timm

model = timm.create_model('deit_tiny_patch16_224', num_classes=7, pretrained=True)

# %%
# Freeze all the weights of the model
for param in model.parameters():
    param.requires_grad = False

# Unfreeze last linear layer
model.head = nn.Linear(192,7)

# %%
print('Total number of parameters:', sum(param.numel() for param in model.parameters()))

# %%
print('Number of trainable parameters:', sum(param.numel() for param in model.parameters() if param.requires_grad))

# %%
if torch.cuda.is_available():
    model = model.cuda()

# %% [markdown]
# # Prepapre a training function and initialize optimizer

# %%
optimizer = torch.optim.Adam(model.parameters(), lr=LR)

# %% [markdown]
# As an indicator of quality, we will use 'Accuracy'

# %%
def accuracy_wb(dataloader, model, label):
    model = model.eval()
    tp = 0
    with torch.no_grad():
        tracker = tqdm(dataloader, total=len(dataloader))
        for batch in tracker:
            image_batch, class_idx_batch = batch
            if torch.cuda.is_available():
                image_batch = image_batch.cuda()
                class_idx_batch = class_idx_batch.cuda()
            
            logits = model(image_batch)
            classes = torch.argmax(logits, dim=1)
            tp += (class_idx_batch == classes).sum().item()

        acc = tp / len(dataloader.dataset)
        wandb.log({label: acc})
        print(label, acc)
    
    return acc

# %% [markdown]
# Start the training process

# %%
from tqdm import tqdm_notebook as tqdm

def train(model, num_epochs, prefix):
    
    wandb.init(project="eye-vision", config={
    "TRAIN_LEN": TRAIN_LEN,
    "TEST_LEN": TEST_LEN,
    "BATCH_SIZE": BATCH_SIZE,
    "EPOCHS": EPOCHS,
    "IMAGE_WIDTH": IMAGE_WIDTH,
    "IMAGE_HEIGHT": IMAGE_HEIGHT,
    "NUM_WORKERS": NUM_WORKERS,
    "SPLIT_DATA": SPLIT_DATA,
    "LR": LR,
    "MODEL_DESC": MODEL_DESC
    })

    wandb.watch(model)

    best_acc = 0.2

    for epoch in range(num_epochs):
        print('\nEpoch', epoch)
        model = model.train()

        tracker = tqdm(train_dataloader, total=len(train_dataloader))
        for batch in tracker:
            optimizer.zero_grad()
            
            image_batch, class_idx_batch = batch
            if torch.cuda.is_available():
                image_batch = image_batch.cuda()
                class_idx_batch = class_idx_batch.cuda()

            logits = model(image_batch)
            loss = F.cross_entropy(logits, class_idx_batch)
            loss.backward()

            wandb.log({'train_loss': loss})

            optimizer.step()

        train_acc = accuracy_wb(train_dataloader, model, 'train_accuracy')
        test_acc = accuracy_wb(test_dataloader, model, 'test_accuracy')

        if (test_acc >= best_acc):
          best_acc = test_acc
          torch.save(model.state_dict(),'drive2/Diplom/ResNet18-64/' + prefix + 'model.pth')
          torch.save(optimizer.state_dict(),'drive2/Diplom/ResNet18-64/' + prefix + 'optimizer.pth')

# %% [markdown]
# # Stage 1 - Training linear layer

# %%
prefix = '_stage_1_'
MODEL_DESC = 'ResNet18' + prefix
train(model, EPOCHS, MODEL_DESC)

# %% [markdown]
# # Stage 2 - Training last layer in main architecture from ResNet

# %%
import torchvision
from torchvision.models import resnet34 as resnet34
from torchvision.models import resnet18 as resnet18

#model = torchvision.models.resnext50_32x4d(pretrained=True)
#model = resnet34(pretrained=True)
model = resnet18(pretrained=True)

# %%
num_ftrs = model.fc.in_features
model.fc = nn.Linear(num_ftrs, 7)
torch.nn.init.xavier_normal_(model.fc.weight)

# %%
model.load_state_dict(torch.load('drive2/Paper/ResNet18-64/ResNet18_stage_1_model.pth'))
#model.load_state_dict(torch.load('drive2/Paper/ResNet34-64/ResNet34_stage_1_model.pth'))
#model.load_state_dict(torch.load('drive2/Paper/ResNetX50-64/ResNetX50_stage_1_model.pth'))

# %%
# Freeze all the weights of the model
for param in model.parameters():
    param.requires_grad = False

# Unfreeze last layer in the main architecture
for param in model.layer4.parameters():
    param.requires_grad = True

# Unfreeze last linear layer
for param in model.fc.parameters():
    param.requires_grad = True

# %% [markdown]
# If you need to change the learning rate

# %%
sd = optimizer.state_dict()
sd['param_groups'][0]['lr'] = 0.0003
optimizer.load_state_dict(sd)
LR = 0.0003

# %%
prefix = '_stage_2_'
MODEL_DESC = 'ResNet18' + prefix
train(model, EPOCHS, MODEL_DESC)

# %% [markdown]
# # Stage 2.1 - Training last layer in main architecture from other models

# %%
# !pip install timm

# %% [markdown]
# EfficientNet_B0

# %%
model = timm.create_model('efficientnet_b0', num_classes=7, pretrained=True)
model.head = nn.Linear(1280,7)
model.load_state_dict(torch.load('drive2/Paper/EfficNetB0-64/efficientnet_b0_stage_1_model.pth'))

# Freeze all the weights of the model
for param in model.parameters():
    param.requires_grad = False

# Unfreeze last layer in the main architecture
i = 0
for param in model.blocks.parameters():
  i = i + 1
  if i > 192: param.requires_grad = True

# Unfreeze last linear layer
model.head = nn.Linear(1280,7)

# %%
prefix = '_stage_2_'
MODEL_DESC = 'EfficientNet_B0' + prefix
train(model, EPOCHS, MODEL_DESC)

# %% [markdown]
# ViT-Tiny

# %%
model = timm.create_model('vit_tiny_patch16_224', num_classes=7, pretrained=True)
model.head = nn.Linear(192,7)
model.load_state_dict(torch.load('drive2/Paper/VIT-64/VIT_stage_1_model.pth'))

# Freeze all the weights of the model
for param in model.parameters():
    param.requires_grad = False

# Unfreeze last layer in the main architecture
i = 0
for param in model.blocks.parameters():
  i = i + 1
  if i > 132: param.requires_grad = True

# Unfreeze last linear layer
model.head = nn.Linear(192,7)

# %%
prefix = '_stage_2_'
MODEL_DESC = 'vit_tiny' + prefix
train(model, EPOCHS, MODEL_DESC)

# %% [markdown]
# # Stage 3 - Testing and inference

# %%
# !pip install timm

# %% [markdown]
# ResNet..

# %%
import torchvision
from torchvision.models import resnet34 as resnet34
from torchvision.models import resnet18 as resnet18

#model = torchvision.models.resnext50_32x4d(pretrained=True)
#model = resnet34(pretrained=True)
model = resnet18(pretrained=True)
num_ftrs = model.fc.in_features
model.fc = nn.Linear(num_ftrs, 7)
torch.nn.init.xavier_normal_(model.fc.weight)

model.load_state_dict(torch.load('drive2/Paper/ResNet18-64/ResNet18_stage_2_model.pth'))
#model.load_state_dict(torch.load('drive2/Paper/ResNet34-64/ResNet34_stage_2_model.pth'))
#model.load_state_dict(torch.load('drive2/Paper/ResNetX50-64/ResNetX50_stage_2_model.pth'))

# %% [markdown]
# EfficientNet_B0

# %%
model = timm.create_model('efficientnet_b0', num_classes=7, pretrained=True)
model.head = nn.Linear(1280,7)
model.load_state_dict(torch.load('drive2/Paper/EfficNetB0-64/efficientnet_b0_stage_2_model.pth'))

# %% [markdown]
# ViT-Tiny

# %%
model = timm.create_model('vit_tiny_patch16_224', num_classes=7, pretrained=True)
model.head = nn.Linear(192,7)
model.load_state_dict(torch.load('drive2/Paper/VIT-64/VIT_stage_2_model.pth'))

# %% [markdown]
# DeiT-Tiny

# %%
model = timm.create_model('deit_tiny_patch16_224', num_classes=7, pretrained=True)
model.head = nn.Linear(192,7)
model.load_state_dict(torch.load('drive2/Paper/DeIT-64/DeIT_stage_1_model.pth'))

# %% [markdown]
# **Important**

# %%
model.eval()

# %% [markdown]
# **Load image**

# %%
my_clsidx_to_labels = ['clean','defocus','drops','full', 'motion', 'partial', 'strong']

# %%
from google.colab.patches import cv2_imshow

image = cv2.imread("2101_RV.png")
h, w = image.shape[:2]
image = cv2.resize(image, (224, 224))
cv2_imshow(image)
image_tensor = torch.Tensor(image).float() / 255
mean = torch.Tensor([0.485, 0.456, 0.406])
std = torch.Tensor([0.229, 0.224, 0.225])

image_tensor = (image_tensor - mean) / std
image_tensor = image_tensor.permute(2, 0, 1)
batch = image_tensor.unsqueeze(0)
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F59EE949110>

# %% [markdown]
# **Get Prediciton**

# %%
if torch.cuda.is_available():
    batch = batch.cuda()

if torch.cuda.is_available():
    model = model.cuda()

# %%
with torch.no_grad():
    logits = model(batch)

# %%
probabilities = torch.nn.Softmax(dim=-1)(logits)
print(probabilities)
sortedProba = torch.argsort(probabilities, dim=-1, descending=True)
print(sortedProba)
text = ""
for (i, idx) in enumerate(sortedProba[0, :3]):
  if (i == 2):
    text = text + "{}: {:.2f}%".format(my_clsidx_to_labels[idx.item()].strip(),probabilities[0, idx.item()] * 100)
  else:
    text = text + "{}: {:.2f}% \n".format(my_clsidx_to_labels[idx.item()].strip(),probabilities[0, idx.item()] * 100)
  
print(text)
# Out:
# tensor([[1.1050e-08, 4.0211e-12, 1.0573e-11, 6.4044e-13, 2.2486e-12, 1.0000e+00,
#          1.3114e-10]], device='cuda:0')
# tensor([[5, 0, 6, 2, 1, 4, 3]], device='cuda:0')
# partial: 100.00%
# clean: 0.00%
# strong: 0.00%

# %% [markdown]
# **Inference time**

# %%
# %%timeit
with torch.no_grad():
    logits = model(batch)
    if torch.cuda.is_available():
        torch.cuda.synchronize()
# Out:
# 100 loops, best of 5: 12.5 ms per loop
